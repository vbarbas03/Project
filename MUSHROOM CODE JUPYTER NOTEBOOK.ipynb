# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('mushrooms.csv')

# %%
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (8,4))
sns.heatmap(df.isnull(), cbar = False, cmap = 'viridis')
plt.title('Heatmap of Missing Values')
plt.show()

# %%
#EDA of the dataset
df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
df['class'].value_counts()
# Out:
# class
# e    4208
# p    3916
# Name: count, dtype: int64

# %%
df['cap-shape'].value_counts()
# Out:
# cap-shape
# x    3656
# f    3152
# k     828
# b     452
# s      32
# c       4
# Name: count, dtype: int64

# %%
df['cap-surface'].value_counts()
# Out:
# cap-surface
# y    3244
# s    2556
# f    2320
# g       4
# Name: count, dtype: int64

# %%
df['cap-color'].value_counts()
# Out:
# cap-color
# n    2284
# g    1840
# e    1500
# y    1072
# w    1040
# b     168
# p     144
# c      44
# u      16
# r      16
# Name: count, dtype: int64

# %%
df['odor'].value_counts()
# Out:
# odor
# n    3528
# f    2160
# s     576
# y     576
# a     400
# l     400
# p     256
# c     192
# m      36
# Name: count, dtype: int64

# %%
#plot of class distribution
sns.countplot(df, x='class', palette = 'viridis')
plt.title('Class Distribution')
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8084\421720062.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df, x='class', palette = 'viridis')

# %%
#i will create a function that will automate the process of the above for all columns
for column in df.columns:
    plt.figure(figsize=(8, 6))
    sns.countplot(x=df[column], palette='viridis') 
    plt.title(f'Distribution of {column}')
    plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8084\2003127671.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[column], palette='viridis')
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8084\2003127671.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[column], palette='viridis')
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8084\2003127671.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[column], palette='viridis')
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8084\2003127671.py:4: FutureWarning:
#
# ...

# %%
# Pairplot of relationship between each column variables
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
#Convert categorical values to numerical
label_encoder = LabelEncoder()
for column in df.columns:
    df[column] = label_encoder.fit_transform(df[column])

# %%
selected_columns = ['class','cap-shape', 'cap-surface', 'cap-color', 'bruises'] 
sns.pairplot(df[selected_columns])
plt.show()

# %%
selected_columns = ['odor', 'gill-attachment', 'gill-spacing', 'gill-size',	'gill-color']
sns.pairplot(df[selected_columns])
plt.show()

# %%
selected_columns = ['stalk-surface-below-ring', 'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type', 'veil-color']
sns.pairplot(df[selected_columns])
plt.show()

# %%
selected_columns = ['ring-type', 'spore-print-color', 'population', 'habitat'] 
sns.pairplot(df[selected_columns])
plt.show()

# %%
#import all necessary libaries
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
import xgboost as xgb

# %%
label_encoder = LabelEncoder()
# I apply label encoding to convert all columns values to float or numerical
for column in df.columns:
    df[column] = label_encoder.fit_transform(df[column])

# %%
x = df.drop(columns=['class'])
y = df['class']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
gnb = GaussianNB()

# %%
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(X_test)

# %%
#Evaluate Gaussian Naive Bayes
accuracy = accuracy_score(y_test,y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print('Accuracy Score:', accuracy)
print('Precision Score', precision)
print('Recall Score', recall)
print('F1 Score', f1)
# Out:
# Accuracy Score: 0.9218461538461539
# Precision Score 0.9098873591989988
# Recall Score 0.9296675191815856
# F1 Score 0.9196710942441493

# %%
#i will define a  function that automate the above, and returns the score
models = {'Gaussian Naive Bayes': GaussianNB(),'Random Forest': RandomForestClassifier(), 'Decision Tree': DecisionTreeClassifier(), 'Logistic Regression': LogisticRegression(), 'Support Vector Classification': SVC(), 'K-Nearest Neighbors': KNeighborsClassifier(), 'XGBoost': xgb.XGBClassifier()}

# %%
def evaluate_model(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    return accuracy, precision, recall, f1

# %%
results = {}

for model_name, model in models.items():
    accuracy, precision, recall, f1 = evaluate_model(model, X_train, X_test, y_train, y_test)
    results[model_name] = {'Accuracy': accuracy, 'Precision': precision, 'Recall': recall, 'F1-Score': f1}
# Out:
# C:\Users\ACER\AppData\Local\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
results_df = pd.DataFrame(results).T
print(results_df)
# Out:
#                                Accuracy  Precision    Recall  F1-Score
# Gaussian Naive Bayes           0.921846   0.909887  0.929668  0.919671
# Random Forest                  1.000000   1.000000  1.000000  1.000000
# Decision Tree                  1.000000   1.000000  1.000000  1.000000
# Logistic Regression            0.947077   0.942748  0.947570  0.945153
# Support Vector Classification  0.992615   0.998705  0.985934  0.992278
# K-Nearest Neighbors            0.996308   0.992386  1.000000  0.996178
# XGBoost                        1.000000   1.000000  1.000000  1.000000

# %%
print('Although, random forest and decision tree performed very well, the best perfoming model is XGboost because it is less prone to overfitting')
# Out:
# Although, random forest and decision tree performed very well, the best perfoming model is XGboost because it is less prone to overfitting

# %%
#Visualization of XGBoost with ROC curve
from sklearn.metrics import roc_curve, auc

# %%
xgb = xgb.XGBClassifier()

# %%
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = xgb.predict(X_test)

# %%
y_proba = xgb.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - XGBoost')
plt.legend(loc='lower right')
plt.show()

# %%
#visualizing random forest
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.tree import plot_tree
rfc = RandomForestClassifier()

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rfc.predict(X_test)

# %%
plt.figure(figsize=(8, 4))
rf_cm = confusion_matrix(y_test, y_pred)
sns.heatmap(rf_cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Poisonous', 'Edible'], yticklabels=['Poisonous', 'Edible'])
plt.title("Random Forest Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
#Visualizing Decision Tree
DT = DecisionTreeClassifier()

# %%
DT.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = DT.predict(X_test)

# %%
plt.figure(figsize=(8, 4))
dt_cm = confusion_matrix(y_test, y_pred)
sns.heatmap(dt_cm, annot=True, fmt='d', cmap='Greens', xticklabels=['Poisonous', 'Edible'], yticklabels=['Poisonous', 'Edible'])
plt.title("Decision Tree Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
plt.figure(figsize=(20, 7))
plot_tree(DT, feature_names=X_test.columns, class_names=['Poisonous', 'Edible'], filled=True, rounded=True)
plt.title("Decision Tree Visualization")
plt.show()
